# %%
Aba <- c(1,3,4,5,6)

# %%
x = Aba

# %%
Anc <- c(3,2,1,4,6)

# %%
y = Anc

# %%
nadine <- function(x,y){
  gue <- x+y
  return(gue) }

# %%
nadine(x,y)
# Out:
# [1]  4  5  5  9 12

# %%
nadine(Aba,Anc)
# Out:
# [1]  4  5  5  9 12
