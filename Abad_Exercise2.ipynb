# %%
install.packages("readr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message in install.packages("readr"):
# “installation of package ‘readr’ had non-zero exit status”

# %%
library(readr)

# %%
Austrian_Media <- read_csv("https://raw.githubusercontent.com/krzlangeles/compeco/refs/heads/main/Austrian-Local-Media.csv")
# Out:
# Rows: 72 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): beginning_of_interval
# dbl (2): post_count, total_interactions
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
class(Austrian_Media)
# Out:
# [1] "spec_tbl_df" "tbl_df"      "tbl"         "data.frame"

# %%
head(Austrian_Media)
# Out:
#   beginning_of_interval post_count total_interactions
# 1 1/1/2015              4125       269593
# 2 2/1/2015              4233       264807
# 3 3/1/2015              4688       276166
# 4 4/1/2015              4594       309416
# 5 5/1/2015              5501       486107
# 6 6/1/2015              5511       635514

# %%
tail(Austrian_Media)
# Out:
#   beginning_of_interval post_count total_interactions
# 1 7/1/2020              7286       1714003
# 2 8/1/2020              6952       1846693
# 3 9/1/2020              7180       2074206
# 4 10/1/2020             7503       1970749
# 5 11/1/2020             7497       2052292
# 6 12/1/2020             7130       2048811

# %%
str(Austrian_Media)
# Out:
# spc_tbl_ [72 × 3] (S3: spec_tbl_df/tbl_df/tbl/data.frame)
#  $ beginning_of_interval: chr [1:72] "1/1/2015" "2/1/2015" "3/1/2015" "4/1/2015" ...
#  $ post_count           : num [1:72] 4125 4233 4688 4594 5501 ...
#  $ total_interactions   : num [1:72] 269593 264807 276166 309416 486107 ...
#  - attr(*, "spec")=
#   .. cols(
#   ..   beginning_of_interval = col_character(),
#   ..   post_count = col_double(),
#   ..   total_interactions = col_double()
#   .. )
#  - attr(*, "problems")=<externalptr>

# %%
Austrian_Media$beginning_of_interval <- as.Date(Austrian_Media$beginning_of_interval)

# %%
str(Austrian_Media)
# Out:
# spc_tbl_ [72 × 3] (S3: spec_tbl_df/tbl_df/tbl/data.frame)
#  $ beginning_of_interval: Date[1:72], format: "1-01-20" "2-01-20" ...
#  $ post_count           : num [1:72] 4125 4233 4688 4594 5501 ...
#  $ total_interactions   : num [1:72] 269593 264807 276166 309416 486107 ...
#  - attr(*, "spec")=
#   .. cols(
#   ..   beginning_of_interval = col_character(),
#   ..   post_count = col_double(),
#   ..   total_interactions = col_double()
#   .. )
#  - attr(*, "problems")=<externalptr>
